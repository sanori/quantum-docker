# %% [markdown]
# # Qiskit Information
# Run this notebook to get the information of the qiskit package that is installed in this kernel.
#
# ## Version Information

# %%
import qiskit
qiskit.__qiskit_version__
# Out:
# {'qiskit-terra': '0.16.4',
#  'qiskit-aer': '0.7.6',
#  'qiskit-ignis': '0.5.2',
#  'qiskit-ibmq-provider': '0.12.2',
#  'qiskit-aqua': '0.8.2',
#  'qiskit': '0.24.1'}

# %%
import qiskit.tools.jupyter
# %qiskit_version_table
# Out:
# <h3>Version Information</h3><table><tr><th>Qiskit Software</th><th>Version</th></tr><tr><td>Qiskit</td><td>0.24.1</td></tr><tr><td>Terra</td><td>0.16.4</td></tr><tr><td>Aer</td><td>0.7.6</td></tr><tr><td>Ignis</td><td>0.5.2</td></tr><tr><td>Aqua</td><td>0.8.2</td></tr><tr><td>IBM Q Provider</td><td>0.12.2</td></tr><tr><th>System information</th></tr><tr><td>Python</td><td>3.8.8 | packaged by conda-forge | (default, Feb 20 2021, 16:22:27)
# [GCC 9.3.0]</td></tr><tr><td>OS</td><td>Linux</td></tr><tr><td>CPUs</td><td>4</td></tr><tr><td>Memory (Gb)</td><td>15.560867309570312</td></tr><tr><td colspan='2'>Thu Apr 01 17:15:06 2021 UTC</td></tr></table>

# %% [markdown]
# ## Visualization Examples

# %%
from qiskit import QuantumCircuit

# %matplotlib inline

qc = QuantumCircuit(3)
qc.h(1)
qc.h(2)
qc.z(2)
qc.draw('mpl')

# %%
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector

state = Statevector.from_instruction(qc)
plot_bloch_multivector(state, title="Bloch Sphere Representation of each Qubits")
# Out:
# /opt/conda/lib/python3.8/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# ## Simulator Example

# %%
qc = QuantumCircuit(2,2)
qc.h(0)
qc.cx(0, 1)
qc.draw()
# Out:
#      ┌───┐
# q_0: ┤ H ├──■──
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├
#           └───┘
# c: 2/══════════

# %%
from qiskit import BasicAer,execute

# Run the quantum circuit on a statevector simulator backend
backend = BasicAer.get_backend('statevector_simulator')
# Create a Quantum Program for execution
job = execute(qc, backend)
result = job.result()
state = result.get_statevector(qc)
print(state)
# Out:
# [0.70710678+0.j 0.        +0.j 0.        +0.j 0.70710678+0.j]

# %%
from qiskit.visualization import plot_state_city
plot_state_city(state)
