# %% [markdown]
# # Qiskit Information
# Run this notebook to get the information of the qiskit package that is installed in this kernel.
#
# ## Version Information

# %%
import qiskit
qiskit.__qiskit_version__
# Out:
# {'qiskit-terra': '0.20.0', 'qiskit-aer': '0.10.4', 'qiskit-ignis': '0.7.0', 'qiskit-ibmq-provider': '0.19.0', 'qiskit-aqua': None, 'qiskit': '0.36.0', 'qiskit-nature': None, 'qiskit-finance': None, 'qiskit-optimization': None, 'qiskit-machine-learning': None}

# %%
import qiskit.tools.jupyter
# %qiskit_version_table
# Out:
# <h3>Version Information</h3><table><tr><th>Qiskit Software</th><th>Version</th></tr><tr><td><code>qiskit-terra</code></td><td>0.20.0</td></tr><tr><td><code>qiskit-aer</code></td><td>0.10.4</td></tr><tr><td><code>qiskit-ignis</code></td><td>0.7.0</td></tr><tr><td><code>qiskit-ibmq-provider</code></td><td>0.19.0</td></tr><tr><td><code>qiskit</code></td><td>0.36.0</td></tr><tr><th>System information</th></tr><tr><td>Python version</td><td>3.9.10</td></tr><tr><td>Python compiler</td><td>GCC 9.4.0</td></tr><tr><td>Python build</td><td>main, Feb  1 2022 21:24:11</td></tr><tr><td>OS</td><td>Linux</td></tr><tr><td>CPUs</td><td>4</td></tr><tr><td>Memory (Gb)</td><td>15.550834655761719</td></tr><tr><td colspan='2'>Sat Apr 09 06:40:45 2022 UTC</td></tr></table>

# %% [markdown]
# ## Visualization Examples

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(3)
qc.h(1)
qc.h(2)
qc.z(2)
qc.draw('mpl')

# %%
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector

state = Statevector.from_instruction(qc)
plot_bloch_multivector(state, title="Bloch Sphere Representation of each Qubits")

# %% [markdown]
# ## Simulator Example

# %%
qc = QuantumCircuit(2,2)
qc.h(0)
qc.cx(0, 1)
qc.draw()
# Out:
#      ┌───┐
# q_0: ┤ H ├──■──
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├
#           └───┘
# c: 2/══════════

# %%
from qiskit import BasicAer,execute

# Run the quantum circuit on a statevector simulator backend
backend = BasicAer.get_backend('statevector_simulator')
# Create a Quantum Program for execution
job = execute(qc, backend)
result = job.result()
state = result.get_statevector(qc)
print(state)
# Out:
# [0.70710678+0.j 0.        +0.j 0.        +0.j 0.70710678+0.j]

# %%
from qiskit.visualization import plot_state_city
plot_state_city(state)
