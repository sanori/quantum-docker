# %% [markdown]
# # Q# (QDK) Information
# Run this notebook to get the information of the qsharp package installed in this kernel.
#
# This notebook checks python kernel only.
# To check Q# kernel, consult [Q# Kernel Test and Examples](qsharpExamples.ipynb).
#
# ## Version Information

# %%
import qsharp
qsharp.__version__
# Out:
# '0.12.2009.2803'

# %% [markdown]
# ## Python and Q# binding
# You can access Q# source files with extension `.qs` as Python package.
#
# In the following example, we can import [NamespaceQFT.qs](NamespaceQFT.qs) as an python module, run and get the results.

# %%
from NamespaceQFT import Perform3qubitQFT

Perform3qubitQFT.simulate()
# Out:
# Initial state |000>:
# |0⟩	1 + 0𝑖
# |1⟩	0 + 0𝑖
# |2⟩	0 + 0𝑖
# |3⟩	0 + 0𝑖
# |4⟩	0 + 0𝑖
# |5⟩	0 + 0𝑖
# |6⟩	0 + 0𝑖
# |7⟩	0 + 0𝑖
# After:
# |0⟩	0.35355339059327384 + 0𝑖
# |1⟩	0.35355339059327384 + 0𝑖
# |2⟩	0.35355339059327384 + 0𝑖
# |3⟩	0.35355339059327384 + 0𝑖
# |4⟩	0.35355339059327384 + 0𝑖
# |5⟩	0.35355339059327384 + 0𝑖
# |6⟩	0.35355339059327384 + 0𝑖
# |7⟩	0.35355339059327384 + 0𝑖
# ()
